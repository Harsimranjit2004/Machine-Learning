# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('TvSales.csv')
df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
plt.scatter(df['TV'],df['Sales'])
plt.xlabel('Amount Spend(TV)')
plt.ylabel('Sales ')
# Out:
# Text(0, 0.5, 'Sales ')

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)
y_test
# Out:
# 112    14.1
# 29     10.5
# 182     8.7
# 199    13.4
# 193    19.6
# 85     15.2
# 10      8.6
# 54     20.2
# 115    12.6
# 35     12.8
# 12      9.2
# 92     19.4
# 13      9.7
# 126     6.6
# 174    11.5
# 2       9.3
# 44      8.5
# 3      18.5
# 113    15.9
# 14     19.0
# 23     15.5
# 25     12.0
# 6      11.8
# 134    10.8
# 165    11.9
# 173    11.7
# 45     14.9
# 65      9.3
# 48     14.8
# 122    11.6
# 178    11.8
# 64     18.0
# 9      10.6
# 57     13.2
# 78      5.3
# 71     12.4
# 128    24.7
# 176    20.2
# 131    12.7
# 53     21.2
# Name: Sales, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
y_pred = lr.predict(X_train)
y_pred
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([20.92435608, 15.14345353, 19.24569109, 13.02413898, 19.96436954,
#        16.72769361, 15.85164032,  6.60324541, 10.41696242,  7.02291165,
#        13.4752802 , 18.23324627, 17.82931751, 16.59130208,  9.83467551,
#        12.32644385,  8.21896046,  7.01766582,  7.59470691, 21.09222258,
#        19.61814489, 18.09685474, 12.20054397, 21.96827587, 21.48041386,
#        10.51663316, 19.88043629,  7.87798163,  7.25372809, 12.05366079,
#        14.78149139,  7.50552784, 19.16175784, 12.65168519,  8.90091811,
#         7.58421526,  7.46880704,  8.91140976, 15.61557806, 21.56959293,
#        19.32437851, 20.56763977, 15.19591181, 15.25361592, 19.11979122,
#        18.63717503, 19.16175784, 14.42477508, 21.76368857, 13.16053051,
#        18.02341315,  7.18028649, 11.49235718, 18.13357554, 12.88774745,
#        21.93155507, 16.41818975, 21.32828484, 17.61948439, 18.02865898,
#        10.66876217, 10.77367873, 16.26606074, 10.52712481, 19.72830728,
#        12.91397659, 19.02012048, 17.00047667, 10.12319605, 16.93228091,
#         8.06683144, 13.65888418, 13.97887969, 15.85164032, 17.76112174,
#         8.6386267 , 11.06219928, 11.61301123, 11.50809467, 12.3736563 ,
#        13.61167173, 17.76636757, 10.19663764, 16.26606074, 22.11515905,
#        11.1408867 , 12.71463513,  9.10025957, 20.2738734 , 19.14602036,
#        19.02012048,  9.69303815,  6.94947006, 14.29362938, 10.56909144,
#        17.01096833,  9.37304263, 11.58678209, 17.18932648,  8.82223069,
#         8.00912733, 15.55262812, 14.06281294, 11.66546951,  8.57043094,
#        16.93228091, 10.15467102, 18.41160443, 13.80052154, 13.35462615,
#        10.57433727, 21.29156405, 13.92642141,  6.78160356, 21.44369306,
#         7.9094566 , 18.52701264, 10.0759836 , 13.88445479,  7.00717417,
#        17.04768912, 17.91849659, 10.57433727, 17.32047218,  7.55274029,
#         7.54749446, 11.2720324 , 11.19859081, 17.9394799 , 13.87396313,
#        21.65352618, 17.62473021, 20.499444  ,  8.82747651, 16.42343558,
#        11.83333601, 11.3087532 ,  9.18943865, 16.05098179, 21.26533491,
#        17.41489709, 10.48515819, 13.8687173 , 18.60570007,  8.55993928,
#        12.48906452, 11.95399005, 19.15126619, 14.41952925, 15.13296187,
#        15.49492401, 16.44966472, 12.87200997, 19.06208711,  7.45306956,
#        17.42014292,  7.25897392,  7.97240654, 16.81687269, 17.86603831])

# %%
plt.scatter(df['TV'],df['Sales'])
plt.plot(X_train,lr.predict(X_train),color= 'red')
plt.xlabel('Input')
plt.ylabel('Output')

plt.savefig("SimpleLinear")

# %% [markdown]
# y_pred

# %%
y_test
# Out:
# 112    14.1
# 29     10.5
# 182     8.7
# 199    13.4
# 193    19.6
# 85     15.2
# 10      8.6
# 54     20.2
# 115    12.6
# 35     12.8
# 12      9.2
# 92     19.4
# 13      9.7
# 126     6.6
# 174    11.5
# 2       9.3
# 44      8.5
# 3      18.5
# 113    15.9
# 14     19.0
# 23     15.5
# 25     12.0
# 6      11.8
# 134    10.8
# 165    11.9
# 173    11.7
# 45     14.9
# 65      9.3
# 48     14.8
# 122    11.6
# 178    11.8
# 64     18.0
# 9      10.6
# 57     13.2
# 78      5.3
# 71     12.4
# 128    24.7
# 176    20.2
# 131    12.7
# 53     21.2
# Name: Sales, dtype: float64

# %%
m = lr.coef_

# %%
b = lr.intercept_

# %%
# y = mx +b 

m*8.58 + b
# Out:
# array([7.01661666])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('placement.csv')
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,1:]

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=2)

# %%
lr =LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
r2Score = r2_score(y_pred, y_test)
r2Score
# Out:
# 0.6626575570753073
