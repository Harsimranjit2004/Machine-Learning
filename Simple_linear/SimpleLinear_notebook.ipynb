# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("./TvSales.csv")
df.describe()
df[df.isnull()].count()
# Out:
# TV       0
# Sales    0
# dtype: int64

# %%
# seperate the colums 
x = df.iloc[:,0].values
y = df.iloc[:,1].values
x,y
type(x)
# Out:
# numpy.ndarray

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)
X_train.shape
X_test.shape
# Out:
# (40,)

# %%
standard = StandardScaler()
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)
standard.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_scaled = standard.transform(X_train)
X_train_scaled = standard.transform(X_test)
X_train_scaled
# Out:
#            0
# 0  -0.960169
# 1  -1.186874
# 2  -0.709849
# 3   1.643399
# 4   0.232395
# 5  -1.113667
# 6  -1.674527
# 7   1.057744
# 8  -1.496233
# 9   0.555922
# 10  1.308064
# 11 -0.747633
# 12  0.071812
# 13  0.440208
# 14 -0.875155
# 15 -0.357983
# 16  1.358837
# 17 -1.768987
# 18 -0.895227
# 19  0.742482
# 20  1.618603
# 21 -0.120651
# 22  0.290252
# 23 -0.222196
# 24 -1.145548
# 25 -0.323741
# 26  0.178080
# 27  0.643298
# 28  0.867642
# 29 -1.480883
# 30 -0.976700
# 31  0.571272
# 32  1.537131
# 33  1.076636
# 34 -1.621393
# 35 -1.556451
# 36 -1.073522
# 37  0.357555
# 38 -0.969615
# 39 -1.482063

# %%
lr = LinearRegression()
lr_scaled = LinearRegression()

lr.fit(X_train,y_train)
#lr_scaled.fit(X_train_scaled,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/harsimranjitsingh/Desktop/machine_learning/Simple_linear/SimpleLinear_notebook.ipynb Cell 7 line 5
#       <a href='vscode-notebook-cell:/Users/harsimranjitsingh/Desktop/machine_learning/Simple_linear/SimpleLinear_notebook.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> lr_scaled = LinearRegression()
#       <a href='vscode-notebook-cell:/Users/harsimranjitsingh/Desktop/machine_learning/Simple_linear/SimpleLinear_notebook.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> lr.fit(X_train,y_train)
# ----> <a href='vscode-notebook-cell:/Users/harsimranjitsingh/Desktop/machine_learning/Simple_linear/SimpleLinear_notebook.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> lr_scaled.fit(X_train_scaled,y_train)
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/linear_model/_base.py:578, in LinearRegression.fit(self, X, y, sample_weight)
#     574 n_jobs_ = self.n_jobs
#     576 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 578 X, y = self._validate_data(
#     579     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     580 )
#     582 has_sw = sample_weight is not None
#     583 if has_sw:
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/utils/validation.py:1210, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1192 X = check_array(
#    1193     X,
#    1194     accept_sparse=accept_sparse,
#    (...)
#    1205     input_name="X",
#    1206 )
#    1208 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1210 check_consistent_length(X, y)
#    1212 return X, y
#
# File /opt/homebrew/lib/python3.11/site-packages/sklearn/utils/validation.py:430, in check_consistent_length(*arrays)
#     428 uniques = np.unique(lengths)
#     429 if len(uniques) > 1:
# --> 430     raise ValueError(
#     431         "Found input variables with inconsistent numbers of samples: %r"
#     432         % [int(l) for l in lengths]
#     433     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [40, 160]

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score,accuracy_score

# %%
r2_score(y_pred, y_test)
# Out:
# 0.3781249875842617
